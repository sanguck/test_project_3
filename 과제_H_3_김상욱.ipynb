# %% [markdown]
# <a href="https://colab.research.google.com/github/sanguck/test_project_3/blob/main/%EA%B3%BC%EC%A0%9C_H_3_%EA%B9%80%EC%83%81%EC%9A%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/FlashChoi5657/Deepnoid-Education.git
# Out:
# Cloning into 'Deepnoid-Education'...
# remote: Enumerating objects: 244, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 244 (delta 50), reused 140 (delta 49), pack-reused 100
# Receiving objects: 100% (244/244), 36.53 MiB | 27.52 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# !pip install simpleitk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 48.4 MB 14 kB/s
# ...

# %%
import SimpleITK as sitk
from skimage.transform import rotate
import cv2 as cv
from keras.preprocessing import image as kimg
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
test_data = './Deepnoid-Education/dataset/test.dcm'
#############################
# fill the blank
# original image 와 augmentation 한 image를 4장을 만드세요 
# 5장의 이미지를 하나의 array로 만드세요
# array를 마지막에 있는 display의 argument로 넣어서 현재 출력된 이미지와 유사하도록 만드세요

# %%
# display 함수는 수정하지 말고 그대로 사용해주세요.
def display(array):
  import matplotlib.pyplot as plt
  for i in range(array.shape[0]):
    plt.imshow(array[i], cmap='gray')
    plt.show()

# %%
# display 함수를 이용해 아래와 같은 이미지를 출력하세요.
Image = sitk.ReadImage(test_data)
img_arr = sitk.GetArrayFromImage(Image)

plt.figure(figsize=(10,10))
plt.imshow(img_arr[0], cmap='gray')

img_rot = rotate(img_arr[0], 20)
plt.figure(figsize=(8,8))
plt.imshow(img_rot, cmap= 'gray' )
plt.show()

img_shift = kimg.random_shift(np.array(img_arr), 0.3, 0.3)
plt.figure(figsize=(8,8))
plt.imshow(img_shift[0], cmap='gray')
plt.show()

img_hflip = np.fliplr(img_arr[0])
plt.figure(figsize=(8,8))
plt.imshow(img_hflip, cmap='gray')
plt.show()

img_vflip = np.flipud(img_arr[0])
plt.figure(figsize=(8,8))
plt.imshow(img_vflip, cmap='gray')
plt.show()

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션
